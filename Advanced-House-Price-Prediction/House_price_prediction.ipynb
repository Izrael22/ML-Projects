# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

## Display all the columns of the dataframe
pd.set_option('display.max_columns', None)

# %%
## print the top5 records
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ### DATA CLEANING

# %%
## print shape of dataset with rows and columns
df.shape
# Out:
# (1460, 81)

# %%
len(df['Id'])
# Out:
# 1460

# %% [markdown]
# since id is unique we don't require it so we drop id column

# %%
del df['Id']

# %%
df.isnull().sum().sort_values(ascending=False)[:20]
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtCond          37
# BsmtQual          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# MSSubClass         0
# dtype: int64

# %% [markdown]
# some features almost doesn't have data so we either add data to them or delete the entire column

# %% [markdown]
# None of these variables seem to be very important, since most of them are not aspects in which we think about
# when buying a house (maybe that's the reason why data is missing?). Moreover, looking closer at the variables,
# we could say that variables like 'PoolQC', 'MiscFeature' and 'FireplaceQu' are strong candidates for outliers,
# so we'll be happy to delete them.

# %%
df.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu'], axis=1, inplace=True)

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].median())

# %%
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    df[col] = df[col].fillna('None')

# %%
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    df[col] = df[col].fillna(0)

# %%
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    df[col] = df[col].fillna(0)

# %%
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    df[col] = df[col].fillna('None')

# %% [markdown]
# the rest have less null values so we drop the null values

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# #### let explore our data

# %%
year = ['YearBuilt','YearRemodAdd','YrSold','GarageYrBlt']
num = [feature for feature in df.columns if df[feature].dtypes!='O']
num_discrete = [feature for feature in num if len(df[feature].unique())<25 and feature not in year]
for feature in num_discrete:
    df.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# as we can see above there is a relationship between variable number and saleprice

# %%
sns.distplot(df['SalePrice'])
# Out:
# C:\Users\fistum graceful\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
year = ['YearBuilt','YearRemodAdd','YrSold','GarageYrBlt']
num = [feature for feature in df.columns if df[feature].dtypes!='O']
num_contnious = [feature for feature in num if len(df[feature].unique())>25 and feature not in year]
for feature in num_contnious:
    plt.hist(df[feature])
    plt.title(feature)
    plt.show()

# %% [markdown]
# as we can see the continous variables are not normally distributed. so we use logarithmic transformation

# %%
for feature in num_contnious:
    if 0 in df[feature].unique():
        pass
    else:
        df[feature] = np.log(df[feature])

# %% [markdown]
# From the Dataset we have 4 year variables. We have extract information from the datetime variables like no of years
# or no of days. One example in this specific scenario can be difference in years between the year the house was built and
# the year the house was sold.

# %%
years = ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']
for feature in years:
    df[feature] = df['YrSold'] - df[feature]

# %%
df.drop(['YrSold'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 0          60       RL     4.174387  9.041922   Pave      Reg         Lvl
# 1          20       RL     4.382027  9.169518   Pave      Reg         Lvl
# 2          60       RL     4.219508  9.328123   Pave      IR1         Lvl
# 3          70       RL     4.094345  9.164296   Pave      IR1         Lvl
# 4          60       RL     4.430817  9.565214   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %% [markdown]
# let's see our categorical feature

# %%
df_categorical = [feature for feature in df.columns if df[feature].dtypes=='O']
for cols in df_categorical:
    print(cols+ ' : ', df[cols].unique())
# Out:
# MSZoning :  ['RL' 'RM' 'C (all)' 'FV' 'RH']
# Street :  ['Pave' 'Grvl']
# LotShape :  ['Reg' 'IR1' 'IR2' 'IR3']
# LandContour :  ['Lvl' 'Bnk' 'Low' 'HLS']
# Utilities :  ['AllPub' 'NoSeWa']
# LotConfig :  ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# LandSlope :  ['Gtl' 'Mod' 'Sev']
# Neighborhood :  ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Condition1 :  ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Condition2 :  ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# BldgType :  ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# HouseStyle :  ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# RoofStyle :  ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# ...

# %% [markdown]
# We will remove categorical variables that are present less than 1% of the observations

# %%
df_categorical = [feature for feature in df.columns if df[feature].dtypes=='O']
for cols in df_categorical:
    print(cols+ ' : ', df[cols].value_counts())
# Out:
# MSZoning :  RL         1145
# RM          218
# FV           62
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# Street :  Pave    1445
# Grvl       6
# Name: Street, dtype: int64
# LotShape :  Reg    918
# IR1    482
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64
# LandContour :  Lvl    1302
# Bnk      63
# HLS      50
# Low      36
# Name: LandContour, dtype: int64
# Utilities :  AllPub    1450
# NoSeWa       1
# Name: Utilities, dtype: int64
# LotConfig :  Inside     1045
# Corner      262
# CulDSac      93
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
# LandSlope :  Gtl    1373
# Mod      65
# Sev      13
# Name: LandSlope, dtype: int64
# Neighborhood :  NAmes      225
# CollgCr    149
# OldTown    113
# Edwards    100
# Somerst     83
# Gilbert     78
# NridgHt     76
# Sawyer      74
# NWAmes      73
# SawyerW     58
# BrkSide     58
# Crawfor     50
# Mitchel     49
# NoRidge     41
# IDOTRR      37
# Timber      37
# ...

# %% [markdown]
# we remove some features like 'Street','LandContour','Condition2','RoofStyle' because there is imbalanced data. and also
# you don't think these columns when you want to buy a house

# %%
df.drop(['Street','Condition2','RoofStyle'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea LotShape LandContour Utilities  \
# 0          60       RL     4.174387  9.041922      Reg         Lvl    AllPub
# 1          20       RL     4.382027  9.169518      Reg         Lvl    AllPub
# 2          60       RL     4.219508  9.328123      IR1         Lvl    AllPub
# 3          70       RL     4.094345  9.164296      IR1         Lvl    AllPub
# 4          60       RL     4.430817  9.565214      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofMatl Exterior1st  \
# ...

# %% [markdown]
# converting categorical features to numerical

# %%
cat_features = [feature for feature in df.columns if df[feature].dtypes=='O']
for feature in cat_features:
    labels_ordered=df.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    df[feature]=df[feature].map(labels_ordered)

# %%
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  LotShape  LandContour  \
# 0          60         3     4.174387  9.041922         0            1
# 1          20         3     4.382027  9.169518         0            1
# 2          60         3     4.219508  9.328123         1            1
# 3          70         3     4.094345  9.164296         1            1
# 4          60         3     4.430817  9.565214         1            1
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  BldgType  \
# 0          1          0          0            15           3         3
# 1          1          2          0            20           1         3
# 2          1          0          0            15           3         3
# 3          1          1          0            17           3         3
# 4          1          2          0            24           3         3
#
#    HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  RoofMatl  \
# ...

# %% [markdown]
# #### FEATURE SCALING

# %%
feature_scale=[feature for feature in df.columns if feature not in 'SalePrice']

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df[feature_scale]=scaler.fit_transform(df[feature_scale])

# %%
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  LotShape  LandContour  \
# 0    0.235294      0.75     0.418208  0.366344  0.000000     0.333333
# 1    0.000000      0.75     0.495064  0.391317  0.000000     0.333333
# 2    0.235294      0.75     0.434909  0.422359  0.333333     0.333333
# 3    0.294118      0.75     0.388581  0.390295  0.333333     0.333333
# 4    0.235294      0.75     0.513123  0.468761  0.333333     0.333333
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  BldgType  \
# 0        1.0       0.00        0.0      0.625000       0.375      0.75
# 1        1.0       0.50        0.0      0.833333       0.125      0.75
# 2        1.0       0.00        0.0      0.625000       0.375      0.75
# 3        1.0       0.25        0.0      0.708333       0.375      0.75
# 4        1.0       0.50        0.0      1.000000       0.375      0.75
#
#    HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  RoofMatl  \
# ...

# %% [markdown]
# #### FEATURE SELECTION

# %%
x = df.drop('SalePrice', axis=1)
y = df['SalePrice']

# %%
#from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.1, random_state=0)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
### Apply Feature Selection
# first, I specify the Lasso Regression model, and I
# select a suitable alpha (equivalent of penalty).
# The bigger the alpha the less features that will be selected.

# Then I use the selectFromModel object from sklearn, which
# will select the features which coefficients are non-zero
feature_sel_model = SelectFromModel(Lasso(alpha=0.005, random_state=0)) 
feature_sel_model.fit(x, y)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
feature_sel_model.get_support()
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#         True, False, False, False,  True, False, False,  True, False,
#        False, False, False, False, False, False, False,  True, False,
#         True, False, False, False, False, False, False, False,  True,
#         True, False,  True, False, False,  True,  True, False, False,
#        False, False, False,  True, False, False,  True,  True, False,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True])

# %%
selected_feat = x.columns[(feature_sel_model.get_support())]
selected_feat
# Out:
# Index(['MSSubClass', 'Neighborhood', 'OverallQual', 'YearRemodAdd', 'BsmtQual',
#        'BsmtExposure', 'HeatingQC', 'CentralAir', '1stFlrSF', 'GrLivArea',
#        'BsmtFullBath', 'KitchenQual', 'Fireplaces', 'GarageType',
#        'GarageFinish', 'GarageCars', 'SaleCondition'],
#       dtype='object')

# %%
x = x[selected_feat]
x.head()
# Out:
#    MSSubClass  Neighborhood  OverallQual  YearRemodAdd  BsmtQual  \
# 0    0.235294      0.625000     0.666667      0.098361      0.75
# 1    0.000000      0.833333     0.555556      0.524590      0.75
# 2    0.235294      0.625000     0.666667      0.114754      0.75
# 3    0.294118      0.708333     0.666667      0.606557      0.50
# 4    0.235294      1.000000     0.777778      0.147541      0.75
#
#    BsmtExposure  HeatingQC  CentralAir  1stFlrSF  GrLivArea  BsmtFullBath  \
# 0          0.25       1.00         1.0  0.356155   0.577712      0.333333
# 1          1.00       1.00         1.0  0.503056   0.470245      0.000000
# 2          0.50       1.00         1.0  0.383441   0.593095      0.333333
# 3          0.25       0.75         1.0  0.399941   0.579157      0.333333
# 4          0.75       1.00         1.0  0.466237   0.666523      0.333333
#
#    KitchenQual  Fireplaces  GarageType  GarageFinish  GarageCars  \
# ...

# %%
df.to_csv("submission.csv", index=False)

# %%
x.shape
# Out:
# (1451, 17)
